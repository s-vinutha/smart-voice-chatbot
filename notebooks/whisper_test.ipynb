# %% [markdown]
# <a href="https://colab.research.google.com/github/s-vinutha/smart-voice-chatbot/blob/main/notebooks/whisper_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q git+https://github.com/openai/whisper.git
# !sudo apt update && sudo apt install ffmpeg
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:4 https://cli.github.com/packages stable/main amd64 Packages [357 B]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,546 kB]
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [89.0 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# ...

# %%
import whisper

print("Downloading and loading the Whisper model...")
# We are using the 'base' model for quick prototyping.
# You can upgrade to 'turbo' or 'large' later for better accuracy!
model = whisper.load_model("base")
print("Model loaded successfully!")
# Out:
# ...
# 100%|███████████████████████████████████████| 139M/139M [00:01<00:00, 89.7MiB/s]
# Model loaded successfully!
